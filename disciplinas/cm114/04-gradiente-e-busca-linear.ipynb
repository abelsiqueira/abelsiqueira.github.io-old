# %% [markdown]
# # Método do Gradiente
#
# O método do Gradiente é definido pela direção de máximo decréscimo
# $d^k = -\nabla f(x^k)$. É importante notar que o método é ineficiente sem a busca linear.
# Aqui, vamos implementar a busca linear de Armijo, que pede que o tamanho de passo $\lambda_k$ seja tal que
# $$ f(x^k + \lambda_kd^k) < f(x^k) + \alpha\lambda_k\nabla f(x^k)^Td^k, $$
# onde $\alpha\in(0,1)$ (usaremos $\alpha = 0.5$.

# %% [markdown]
# Vamos considerar como teste inicial a função
# $$ f(x) = 4x_1^2 + 9x_2^2, $$
# cujo gradiente é
# $$ \nabla f(x) = \left(\begin{array}{c} 8x_1 \\ 18x_2 \end{array}\right), $$
# a partir do ponto $x^0 = (1,1)$.

# %%
f(x) = 4x[1]^2 + 9*x[2]^2;
∇f(x) = [8*x[1]; 18*x[2]];
x0 = [1.0; 1.0];

# %%
using Plots
gr()
contour(linspace(-3,3,100), linspace(-3,3,100),
    (x,y)->f([x;y]))
scatter!([x0[1]], [x0[2]], c=:blue, leg=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   128.317,371.481 128.317,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   285.748,371.481 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   443.179,371.481 443.179,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,307.847 528.554,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,190.507 528.554,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,73.1675 528.554,73.1675
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   128.317,377.078 128.317,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   128.317,3.93701 128.317,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,377.078 285.748,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,3.93701 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   443.179,377.078 443.179,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   443.179,3.93701 443.179,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,307.847 42.9425,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,307.847 528.554,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,190.507 42.9425,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,190.507 528.554,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,73.1675 42.9425,73.1675
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,73.1675 528.554,73.1675
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 128.317, 393.878)" x="128.317" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 285.748, 393.878)" x="285.748" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 443.179, 393.878)" x="443.179" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 312.347)" x="29.4331" y="312.347">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 195.007)" x="29.4331" y="195.007">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 77.6675)" x="29.4331" y="77.6675">2</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#f3e258; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,360.599 54.3725,362.213 56.6336,362.962 59.1431,363.776 63.9137,365.292 67.8547,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#fabf26; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,350.33 54.3725,352.051 55.062,352.294 59.1431,353.705 63.9137,355.32 65.5147,355.85 68.6844,356.878 73.455,358.391 76.728,359.406 78.2256,359.861
#   82.9963,361.276 87.7669,362.659 88.8359,362.962 92.5375,363.988 97.3081,365.278 102.01,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#fb9c07; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   144.199,366.517 140.244,365.715 135.473,364.715 130.703,363.683 127.468,362.962 125.932,362.612 121.161,361.492 116.391,360.34 112.63,359.406 111.62,359.149
#   106.849,357.905 102.079,356.628 99.25,355.85 97.3081,355.305 92.5375,353.93 87.7669,352.522 87.0144,352.294 82.9963,351.052 78.2256,349.542 75.7454,348.739
#   73.455,347.98 68.6844,346.364 65.2749,345.183 63.9137,344.7 59.1431,342.973 55.503,341.627 54.3725,341.199 49.6018,339.355
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#f57d15; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,327.513 54.3725,329.498 57.9567,330.96 59.1431,331.431 63.9137,333.288 67.1352,334.515 68.6844,335.091 73.455,336.826 76.9584,338.071 78.2256,338.511
#   82.9963,340.129 87.5184,341.627 87.7669,341.707 92.5375,343.214 97.3081,344.684 98.9672,345.183 102.079,346.096 106.849,347.461 111.435,348.739 111.62,348.789
#   116.391,350.053 121.161,351.282 125.204,352.294 125.932,352.472 130.703,353.606 135.473,354.706 140.244,355.771 140.612,355.85 145.014,356.781 149.785,357.756
#   154.556,358.698 158.277,359.406 159.326,359.601 164.097,360.457 168.868,361.28 173.638,362.071 178.409,362.828 179.29,362.962 183.179,363.54 187.95,364.217
#   192.721,364.862 197.491,365.475 202.262,366.056 206.278,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#9e2a62; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,262.744 50.4111,263.4 54.3725,266.462 55.0247,266.956 59.1431,269.933 59.9615,270.512 63.9137,273.187 65.2425,274.068 68.6844,276.253 70.8908,277.623

# %%
d = -∇f(x0)
# Out:
# 2-element Array{Float64,1}:
#   -8.0
#  -18.0

# %%
contour(linspace(-3,3,100), linspace(-3,3,100),
    (x,y)->f([x;y]))
scatter!([x0[1]], [x0[2]], c=:blue, leg=false)
x1 = x0 + d
scatter!([x1[1]], [x1[2]], c=:blue, leg=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   96.8311,371.481 96.8311,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   191.29,371.481 191.29,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   285.748,371.481 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   380.207,371.481 380.207,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   474.665,371.481 474.665,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,331.315 528.554,331.315
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,243.31 528.554,243.31
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,155.305 528.554,155.305
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,67.3005 528.554,67.3005
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   96.8311,377.078 96.8311,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   96.8311,3.93701 96.8311,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   191.29,377.078 191.29,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   191.29,3.93701 191.29,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,377.078 285.748,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,3.93701 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   380.207,377.078 380.207,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   380.207,3.93701 380.207,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   474.665,377.078 474.665,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   474.665,3.93701 474.665,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,331.315 42.9425,331.315
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,331.315 528.554,331.315
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,243.31 42.9425,243.31
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,243.31 528.554,243.31
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,155.305 42.9425,155.305
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,155.305 528.554,155.305
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,67.3005 42.9425,67.3005
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,67.3005 528.554,67.3005
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 96.8311, 393.878)" x="96.8311" y="393.878">-6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 191.29, 393.878)" x="191.29" y="393.878">-4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 285.748, 393.878)" x="285.748" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.207, 393.878)" x="380.207" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.665, 393.878)" x="474.665" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 335.815)" x="29.4331" y="335.815">-15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 247.81)" x="29.4331" y="247.81">-10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 159.805)" x="29.4331" y="159.805">-5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 71.8005)" x="29.4331" y="71.8005">0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#f3e258; stroke-width:0.8; stroke-opac

# %%
t = 1.0
f(x0+t*d), f(x0)+0.5*t*dot(∇f(x0),d)
# Out:
# (2797.0,-181.0)

# %% [markdown]
# Como $f(x^0+d) > f(x^0)$, então a condição de Armijo não é satisfeito. Vamos atualizar o tamanho do passo sempre multiplicando o passo por 0.9.
# Então

# %%
t = t*0.9
f(x0+t*d), f(x0)+0.5*t*dot(∇f(x0),d)
# Out:
# (2233.1200000000003,-161.6)

# %% [markdown]
# O valor já melhorou. Vamos tentar de novo.

# %%
t = t*0.9
f(x0+t*d), f(x0)+0.5*t*dot(∇f(x0),d)
# Out:
# (1779.8692000000003,-144.14000000000001)

# %%
t = t*0.9
f(x0+t*d), f(x0)+0.5*t*dot(∇f(x0),d)
# Out:
# (1.1636771925145442,1.7189510214102182)

# %%
t
# Out:
# 0.05814973700304011

# %% [markdown]
# Como vemos, a ideia é repetir esse diminuição de $t$ até que a condição seja satisfeita. Vamos fazer isso com o while

# %%
t = 1.0
while f(x0 + t*d) > f(x0) + 1e-2*t*dot(∇f(x0),d)
    t = t*0.5;
end
t
# Out:
# 0.0625

# %%
x1 = x0 + (t/0.5)*d
contour(linspace(-3,3,100), linspace(-3,3,100),
    (x,y)->f([x;y]))
scatter!([x0[1]], [x0[2]], c=:blue, leg=false)
scatter!([x1[1]], [x1[2]], c=:blue, leg=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   128.317,371.481 128.317,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   285.748,371.481 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   443.179,371.481 443.179,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,307.847 528.554,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,190.507 528.554,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,73.1675 528.554,73.1675
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   128.317,377.078 128.317,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   128.317,3.93701 128.317,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,377.078 285.748,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   285.748,3.93701 285.748,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   443.179,377.078 443.179,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   443.179,3.93701 443.179,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,307.847 42.9425,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,307.847 528.554,307.847
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,190.507 42.9425,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,190.507 528.554,190.507
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,73.1675 42.9425,73.1675
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,73.1675 528.554,73.1675
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 128.317, 393.878)" x="128.317" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 285.748, 393.878)" x="285.748" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 443.179, 393.878)" x="443.179" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 312.347)" x="29.4331" y="312.347">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 195.007)" x="29.4331" y="195.007">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 77.6675)" x="29.4331" y="77.6675">2</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#f3e258; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,360.599 54.3725,362.213 56.6336,362.962 59.1431,363.776 63.9137,365.292 67.8547,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#fabf26; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,350.33 54.3725,352.051 55.062,352.294 59.1431,353.705 63.9137,355.32 65.5147,355.85 68.6844,356.878 73.455,358.391 76.728,359.406 78.2256,359.861
#   82.9963,361.276 87.7669,362.659 88.8359,362.962 92.5375,363.988 97.3081,365.278 102.01,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#fb9c07; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   144.199,366.517 140.244,365.715 135.473,364.715 130.703,363.683 127.468,362.962 125.932,362.612 121.161,361.492 116.391,360.34 112.63,359.406 111.62,359.149
#   106.849,357.905 102.079,356.628 99.25,355.85 97.3081,355.305 92.5375,353.93 87.7669,352.522 87.0144,352.294 82.9963,351.052 78.2256,349.542 75.7454,348.739
#   73.455,347.98 68.6844,346.364 65.2749,345.183 63.9137,344.7 59.1431,342.973 55.503,341.627 54.3725,341.199 49.6018,339.355
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#f57d15; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,327.513 54.3725,329.498 57.9567,330.96 59.1431,331.431 63.9137,333.288 67.1352,334.515 68.6844,335.091 73.455,336.826 76.9584,338.071 78.2256,338.511
#   82.9963,340.129 87.5184,341.627 87.7669,341.707 92.5375,343.214 97.3081,344.684 98.9672,345.183 102.079,346.096 106.849,347.461 111.435,348.739 111.62,348.789
#   116.391,350.053 121.161,351.282 125.204,352.294 125.932,352.472 130.703,353.606 135.473,354.706 140.244,355.771 140.612,355.85 145.014,356.781 149.785,357.756
#   154.556,358.698 158.277,359.406 159.326,359.601 164.097,360.457 168.868,361.28 173.638,362.071 178.409,362.828 179.29,362.962 183.179,363.54 187.95,364.217
#   192.721,364.862 197.491,365.475 202.262,366.056 206.278,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#9e2a62; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,262.744 50.4111,263.4 54.3725,266.462 55.0247,266.956 59.1431,269.933 59.9615,270.512 63.9137,273.187 65.2425,274.068 68.6844,276.253 70.8908,277.623

# %% [markdown]
# O método se repete agora a partir de x1

# %%
d = -∇f(x1);
t = 1.0;
while f(x1 + t*d) > f(x1) + 0.5*t*dot(∇f(x1),d)
    t = t*0.9;
end
x2 = x1 + t*d
# Out:
# 2-element Array{Float64,1}:
#   0.0
#  -0.0724678

# %%
d = -∇f(x2);
t = 1.0;
while f(x2 + t*d) > f(x2) + 0.5*t*dot(∇f(x2),d)
    t = t*0.9;
end
x3 = x2 + t*d
# Out:
# 2-element Array{Float64,1}:
#   0.0
#  -0.00420127

# %% [markdown]
# Nós precisamos repetir esses passos até que $\Vert\nabla f(x^k)\Vert$ seja suficientemente pequeno. Pra fazer isso, vamos usar apenas uma variável para $x^k$ e atualizá-la.

# %%
x = copy(x0); # Cópia de x0
while norm(∇f(x)) > 1e-5
    d = -∇f(x);
    t = 1.0;
    while f(x + t*d) > f(x) + 0.01*t*dot(∇f(x),d)
        t = t*0.1;
    end
    x = x + t*d
end
x
# Out:
# 2-element Array{Float64,1}:
#   3.68935e-46
#  -5.02168e-7

# %% [markdown]
# Agora sim, temos a solução esperada (suficientemente próximo).
#
# O método então, será esse código. Vamos criar uma função para ele (sempre crie funções)

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    x = copy(x0) # Cópia de x0
    while norm(∇f(x)) > 1e-5
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
    end
    return x # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %% [markdown]
# Agora podemos brincar com essa função, mudando $f$ e $\nabla f$.

# %%
f(x) = (x[1]-1)^2 + 4*(x[2]-2)^2
∇f(x) = [2*(x[1]-1); 8*(x[2]-2)];
x = gradient_method(f, ∇f, [0.0; 0.0])
# Out:
# 2-element Array{Float64,1}:
#  0.999997
#  2.0

# %% [markdown]
# Inclusive, podemos usar a notação `x->` para definir uma função na hora de chamar a função do método (para testar).

# %%
x = gradient_method(x->x[1]^2 + (1-x[2])^2,
    x->[2*x[1]; -2*(1-x[2])], [2.0;3.0])
# Out:
# 2-element Array{Float64,1}:
#  3.08169e-7
#  1.0

# %% [markdown]
# Vamos testar também com a famosa função de Rosenbrock

# %%
f(x) = (1-x[1])^2 + 100*(x[2]-x[1]^2)^2;
∇f(x) = [-2*(1-x[1]) - 400*x[1]*(x[2]-x[1]^2);
         200*(x[2] - x[1]^2)]; # Posso escrever separado para ficar mais fácil de visualizar
x0 = [1.2; -0.8];
contour(linspace(-2,3,100), linspace(-2,3,100),
    (x,y)->f([x;y]), levels=200)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   35.4331,371.481 35.4331,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   135.559,371.481 135.559,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   235.685,371.481 235.685,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   335.811,371.481 335.811,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   435.937,371.481 435.937,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   536.063,371.481 536.063,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,377.078 528.554,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,302.45 528.554,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,227.822 528.554,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,153.193 528.554,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,78.5652 528.554,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,3.93701 528.554,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 35.4331,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   135.559,377.078 135.559,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   135.559,3.93701 135.559,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   235.685,377.078 235.685,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   235.685,3.93701 235.685,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   335.811,377.078 335.811,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   335.811,3.93701 335.811,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435.937,377.078 435.937,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435.937,3.93701 435.937,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,3.93701 536.063,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 42.9425,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 528.554,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,302.45 42.9425,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,302.45 528.554,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,227.822 42.9425,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,227.822 528.554,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,153.193 42.9425,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,153.193 528.554,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,78.5652 42.9425,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,78.5652 528.554,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 42.9425,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,3.93701 528.554,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.4331, 393.878)" x="35.4331" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 135.559, 393.878)" x="135.559" y="393.878">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 235.685, 393.878)" x="235.685" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text sty

# %%
function gradient_method_scatter(f, ∇f, x0, p) # Precisamos dar um nome e colocar os argumentos de entrada
    x = copy(x0) # Cópia de x0
    scatter!(p, [x[1]], [x[2]], c=:blue, leg=false)
    while norm(∇f(x)) > 1e-2
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        y = x + t*d
        plot!(p, [x[1]; y[1]], [x[2]; y[2]], c=:blue)
        x = y
        scatter!(p, [x[1]], [x[2]], c=:blue, ms=2)
    end
    return x # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method_scatter (generic function with 1 method)

# %%
f(x) = (1-x[1])^2 + 100*(x[2]-x[1]^2)^2;
∇f(x) = [-2*(1-x[1]) - 400*x[1]*(x[2]-x[1]^2);
         200*(x[2] - x[1]^2)]; # Posso escrever separado para ficar mais fácil de visualizar
x0 = [-1.2; 1.1];
p = contour(linspace(-2,3,100), linspace(-2,3,100),
    (x,y)->f([x;y]), levels=200)
x = gradient_method_scatter(f, ∇f, x0, p)
p
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   49.6018,371.481 49.6018,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   238.519,371.481 238.519,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   427.436,371.481 427.436,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,366.517 528.554,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,225.709 528.554,225.709
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,84.9015 528.554,84.9015
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,377.078 49.6018,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,3.93701 49.6018,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   238.519,377.078 238.519,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   238.519,3.93701 238.519,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   427.436,377.078 427.436,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   427.436,3.93701 427.436,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,366.517 42.9425,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,366.517 528.554,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,225.709 42.9425,225.709
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,225.709 528.554,225.709
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,84.9015 42.9425,84.9015
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,84.9015 528.554,84.9015
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 49.6018, 393.878)" x="49.6018" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 238.519, 393.878)" x="238.519" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 427.436, 393.878)" x="427.436" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 371.017)" x="29.4331" y="371.017">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 230.209)" x="29.4331" y="230.209">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 89.4015)" x="29.4331" y="89.4015">2</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#66156e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.3108,366.517 53.1193,362.962 51.9176,359.406 50.7053,355.85 49.6018,352.639
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#68166e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,356.531 50.5898,359.406 51.803,362.962 53.0058,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#69166e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   51.7008,366.517 50.4867,362.962 49.6018,360.386
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#6d186e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   50.3957,366.517 49.6018,364.207
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#60136e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   58.4634,366.517 57.2352,362.962 55.996,359.406 54.7455,355.85 54.3725,354.792 53.5361,352.294 52.3382,348.739 51.1296,345.183 49.9101,341.627 49.6018,340.73
#
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#5e126e; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,336.68 50.0801,338.071 51.2982,341.627 52.5052,345.183 53.7015,348.739 54.3725,350.743 54.9197,352.294 56.1687,355.85 57.4064,359.406 58.633,362.962
#   59.1431,364.446 59.8931,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#5a116d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   62.8376,366.517 61.5725,362.962 60.2958,359.406 59.1431,356.222 59.0151,355.85 57.7923,352.294 56.5582,348.739 55.3127,345.183 54.3725,342.518 54.0744,341.627
#   52.8818,338.071 51.6782,334.515 50.4635,330.96 49.6018,328.454
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#58106d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.6018,324.276 50.6777,327.404 51.8905,330.96 53.092,334.515 54.2826,338.071 54.3725,338.34 55.5322,341.627 56.7758,345.183 58.0078,348.739 59.1431,352.043
#   59.234,352.294 60.5208,355.85 61.7955,359.406 63.0584,362.962 63.9137,365.385 64.335,366.517
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#540e6d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   67.467,366.517 66.1655,362.962 64.8515,359.406 63.9137,356.885 63.5484,355.85 62.2903,352.294 61.0204,348.739 59.73

# %%
contour(linspace(-2,3,400), linspace(-2,3,400),
(x,y)->f([x;y]), levels=[0.05;0.5;1;5])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="501" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   35.4331,371.481 35.4331,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   135.559,371.481 135.559,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   235.685,371.481 235.685,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   335.811,371.481 335.811,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   435.937,371.481 435.937,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   536.063,371.481 536.063,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,377.078 528.554,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,302.45 528.554,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,227.822 528.554,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,153.193 528.554,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,78.5652 528.554,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   42.9425,3.93701 528.554,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 536.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 35.4331,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   135.559,377.078 135.559,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   135.559,3.93701 135.559,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   235.685,377.078 235.685,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   235.685,3.93701 235.685,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   335.811,377.078 335.811,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   335.811,3.93701 335.811,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435.937,377.078 435.937,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435.937,3.93701 435.937,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,3.93701 536.063,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 536.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 42.9425,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,377.078 528.554,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,302.45 42.9425,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,302.45 528.554,302.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,227.822 42.9425,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,227.822 528.554,227.822
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,153.193 42.9425,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,153.193 528.554,153.193
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,78.5652 42.9425,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,78.5652 528.554,78.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 42.9425,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   536.063,3.93701 528.554,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.4331, 393.878)" x="35.4331" y="393.878">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 135.559, 393.878)" x="135.559" y="393.878">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 235.685, 393.878)" x="235.685" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text sty

# %%
x = gradient_method(f, ∇f, x0)
# Out:
# 2-element Array{Float64,1}:
#  0.999989
#  0.999978

# %% [markdown]
# Isso conclui o básico do método.

# %% [markdown]
# ## Mais informações na implementação
#
# Apesar do método estar implementado, queremos mais informações dele.
# Queremos saber **quantas iterações** ele leva pra convergir e **em quanto tempo**.
# Rapidamente, podemos fazer a parte de iterações.

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    x = copy(x0) # Cópia de x0
    iter = 0
    while norm(∇f(x)) > 1e-5
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
    end
    return x, iter # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, iter = gradient_method(f, ∇f, x0)
# Out:
# ([0.9999891261933653,0.9999782129526038],1816)

# %% [markdown]
# Para calcular o tempo temos as funções `tic` e `toc`, similares às funções do MatLab, mas vamos usar a função `time`, que é melhor para fazer comparações (que faremos depois).

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    while norm(∇f(x)) > 1e-5
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
    end
    elapsed_time = time() - start_time
    return x, iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, iter, el_time = gradient_method(f, ∇f, x0)
# Out:
# ([0.9999891261933653,0.9999782129526038],1816,0.035060882568359375)

# %% [markdown]
# Além disso, também queremos o valor da função e do gradiente na solução.

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    while norm(∇f(x)) > 1e-5
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
    end
    elapsed_time = time() - start_time
    return x, f(x), ∇f(x), iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, fx, ∇fx, iter, el_time = gradient_method(f, ∇f, x0)
# Out:
# ([0.9999891261933653,0.9999782129526038],1.183961096977204e-10,[-5.926838706009923e-6,-7.910473298622378e-6],1816,0.03397202491760254)

# %% [markdown]
# Agora, vamos limitar o número de iterações e o tempo de execução do algoritmo.
# Para isso, vamos criar variáveis para essas quantidades. Depois vamos querer receber esses valores na chamada de função. Também vamos criar uma variável para a tolerância.

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    tol = 1e-5
    max_iter = 1000
    max_time = 60 # Em segundos
    
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    elapsed_time = 0.0
    while norm(∇f(x)) > tol
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
        if iter >= max_iter
            break
        end
        elapsed_time = time() - start_time
        if elapsed_time >= max_time
            break
        end
    end
    return x, f(x), ∇f(x), iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, fx, ∇fx, iter, el_time = gradient_method(f, ∇f, x0)
# Out:
# ([0.9994031107078174,0.9988039099625171],3.56988505428105e-7,[-0.00012732354220518585,-0.0005335459889677097],1000,0.03200101852416992)

# %% [markdown]
# Note como o método agora não convergiu para esse problema. Da maneira que retornamos o valor do algoritmo, não temos como saber disso. Vamos criar uma variável sinalizando a saída (*exit flag*).
# O mais utilizando para o exit flag é que se ele é 0, então ele convergiu. Cada outro valor indica um tipo de problema que aconteceu. Vamos usar 1 para o máximo de iterações e 2 para o máximo de tempo.

# %%
function gradient_method(f, ∇f, x0) # Precisamos dar um nome e colocar os argumentos de entrada
    tol = 1e-5
    max_iter = 1000
    max_time = 60 # Em segundos
    exit_flag = 0
    
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    elapsed_time = 0.0
    while norm(∇f(x)) > tol
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
        if iter >= max_iter
            exit_flag = 1
            break
        end
        elapsed_time = time() - start_time
        if elapsed_time >= max_time
            exit_flag = 2
            break
        end
    end
    return x, f(x), ∇f(x), exit_flag, iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, x0)
exit_flag
# Out:
# 1

# %% [markdown]
# Agora vamos colocar os parâmetros `tol`, `max_iter` e `max_time` como parâmetros de entrada da função.
# No entanto, algumas coisas têm que ser observadas. Esses parâmetros devem ser **opcionais**, com um **valor padrão**, caso o usuário não queira usá-los.
# Em Julia, para criar uma parâmetro opcional, basta colocar o valor padrão na chamada, mas **todos** os argumentos opcionais devem estar à direita.

# %%
function media(a, b, p1 = 1.0, p2 = 1.0) # Função que calcula média ponderada.
    return (a*p1 + b*p2)/(p1+p2)
end
# Out:
# media (generic function with 3 methods)

# %%
media(3,5) # Chamada assim, os pesos são 1.0 e 1.0
# Out:
# 4.0

# %%
media(3,5,3.0,2.0) # Pesos 3 e 2
# Out:
# 3.8

# %%
media(3,5,3.0) # Pesos 3 e 1
# Out:
# 3.5

# %% [markdown]
# Para calcular a média mudando o peso do segundo parâmetro, é obrigatório passar o peso do primeiro.
#
# No nosso caso, isso é infactível, pois o usuário pode querer mudar apenas um dos parâmetros.
# Para resolver esse problema, vamos usar **argumentos de palavra chave** (*keyword argument*).
# Esses argumentos devem ser colocados depois de um `;` na chamada de função, e eles devem ser chamados usando o nome do parâmetro.

# %%
function media(a, b; p1 = 1.0, p2 = 1.0)
    return (a*p1 + b*p2)/(p1+p2)
end
# Out:
# media (generic function with 3 methods)

# %%
media(3,5)
# Out:
# 4.0

# %%
media(3,5, p1=2)
# Out:
# 3.6666666666666665

# %%
media(3,5, p2=2)
# Out:
# 4.333333333333333

# %%
media(3,5, p1=3,p2=2)
# Out:
# 3.8

# %% [markdown]
# Agora ao nosso caso.

# %%
function gradient_method(f, ∇f, x0; tol = 1e-5, max_iter = 1000,
        max_time = 60)
    exit_flag = 0
    
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    elapsed_time = 0.0
    while norm(∇f(x)) > tol
        d = -∇f(x)
        t = 1.0
        while f(x + t*d) > f(x) + 0.5*t*dot(∇f(x),d)
            t = t*0.9
        end
        x = x + t*d
        iter = iter + 1
        if iter >= max_iter
            exit_flag = 1
            break
        end
        elapsed_time = time() - start_time
        if elapsed_time >= max_time
            exit_flag = 2
            break
        end
    end
    return x, f(x), ∇f(x), exit_flag, iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, x0)
# Out:
# ([0.9995984253018871,0.9991921835512458],1.63593500512932e-7,[0.0011274009387797395,-0.0009656629533116856],1,1000,0.03673601150512695)

# %%
x, fx, ∇fx, exit_flag, iter, el_time =
gradient_method(f, ∇f, x0, tol=1e-2)
# Out:
# ([0.9890522215376949,0.9781775390129743],0.00012007248352754047,[-0.003397148775394463,-0.00935158313504214],0,237,0.008003950119018555)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, x0, tol=1e-3)
# Out:
# ([0.9989210992904697,0.9978385406541873],1.1663518645739358e-6,[-0.00023110098545843223,-0.0009643906986100959],0,872,0.0186460018157959)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, x0, max_iter=5000, tol=1e-8)
# Out:
# ([0.999999989127975,0.999999978216308],1.1835807667890093e-16,[-5.887178694853094e-9,-7.92843568575563e-9],0,3190,0.06446409225463867)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, x0, max_iter=5000, tol=1e-8, max_time=0.1)
# Out:
# ([0.999999989127975,0.999999978216308],1.1835807667890093e-16,[-5.887178694853094e-9,-7.92843568575563e-9],0,3190,0.05345606803894043)

# %% [markdown]
# Pra finalizar, devemos nos preocupar com a **qualidade** da implementação. Podemos levar isso a vários níveis, mas vamos nos preocupar, por enquanto, apenas com chamadas desnecessária de função.

# %%
n = 1000; (Q,R) = qr(rand(n,n));
G = Q*diagm(linspace(1,100,n))*Q'; # Uma matriz nxn com número de condição 100.
g = rand(n);
f(x) = 0.5*dot(x,G*x) + dot(g,x);
∇f(x) = G*x + g;
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, zeros(n));
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, zeros(n)); # Rodando duas vezes
println("exit_flag = $exit_flag")
println("iter = $iter")
println("el_time = $el_time")
# Out:
# exit_flag = 0
# iter = 266
# el_time = 4.122524976730347

# %% [markdown]
# Em Julia, as coisas são compiladas enquanto vão sendo feitas, então para comparar tempo, temos que rodar a função a primeira vez só para compilá-la.
#
# Nesse exemplo, criamos uma função quadrática
# $$ f(x) = \frac{1}{2}x^TGx + x^Tg, $$
# onde a matriz $G$ é simétrica definida positiva e com número de condição 100, i.e., bem comportada.
# A dimensão de $G$ é 1000, mas o número de iterações que precisamos para convergência é bem menor que 1000.
# No entanto, o tempo que o algoritmo leva para convergir é bem maior que no exemplo de Rosenbrock.
# Isso acontece porque cada avaliação da função $f$ e de $\nabla f$ tem uma multiplicação por matriz, o que deixa o método mais lento.
# Então, precisamos diminuir o número de avaliações. A mudança abaixo, reduz drasticamente a quantidade de avaliações de função que fazemos.

# %%
function gradient_method(f, ∇f, x0; tol = 1e-5, max_iter = 1000, max_time = 60)
    exit_flag = 0
    
    x = copy(x0) # Cópia de x0
    iter = 0
    start_time = time()
    elapsed_time = 0.0
    fx = f(x)
    ∇fx = ∇f(x)
    while norm(∇fx) > tol
        d = -∇fx
        ∇fx_dot_d = dot(∇fx, d)
        t = 1.0
        while f(x + t*d) > fx + 0.5*t*∇fx_dot_d
            t = t*0.9
        end
        x = x + t*d
        fx = f(x)
        ∇fx = ∇f(x)
        iter = iter + 1
        if iter >= max_iter
            exit_flag = 1
            break
        end
        elapsed_time = time() - start_time
        if elapsed_time >= max_time
            exit_flag = 2
            break
        end
    end
    return x, fx, ∇fx, exit_flag, iter, elapsed_time # Precisamos retornar o ponto encontrado
end
# Out:
# gradient_method (generic function with 1 method)

# %%
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, zeros(n));
x, fx, ∇fx, exit_flag, iter, el_time = gradient_method(f, ∇f, zeros(n)); # Rodando duas vezes
println("exit_flag = $exit_flag")
println("iter = $iter")
println("el_time = $el_time")
# Out:
# exit_flag = 0
# iter = 266
# el_time = 1.5661399364471436

# %% [markdown]
# Comparando o tempo das duas, vemos a economia obtida.
#
# Algumas outras melhorias podem ser feitas, mas não vamos nos preocupar com elas agora.
