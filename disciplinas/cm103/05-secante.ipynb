# %%
using FactCheck, ForwardDiff, Plots

# %%
function newton(f, x; tol_f = 1e-6, tol_x = 1e-3,
        maxiter = 1000, maxtime = 60)
    tol_g = tol_f^2
    g(x) = ForwardDiff.derivative(f, x)
    escala = max( abs(g(x)), abs(f(x)) )
    if abs(g(x)) < tol_g * escala
        return x, -1, f(x), g(x), 0, 0.0
    end
    d = -f(x)/g(x)
    iter = 0
    ef = 0
    start_time = time()
    el_time = 0.0
    while abs(f(x)) > tol_f || abs(d) > tol_x
        x = x + d
        if abs(g(x)) < tol_g * escala
            ef = -1
            break
        end
        d = -f(x)/g(x)
        iter += 1
        el_time = time() - start_time
        if iter >= maxiter
            ef = 1
            break
        end
        if el_time >= maxtime
            ef = 2
            break
        end
    end
    return x, ef, f(x), g(x), iter, el_time
end
# Out:
# newton (generic function with 1 method)

# %%
context("Exemplos básicos") do
    facts("f(x) = x^2 - 1") do
        f(x) = x^2-1
        x, ef, fx, fdx, iter, el_time = newton(f, 1.0)
        @fact x --> roughly(1.0, 1e-6)
        @fact ef --> 0
        @fact fx --> roughly(0.0, 1e-6)
        @fact iter --> less_than(1000)
        @fact el_time --> less_than(60)
    end
    
    facts("f(x) = x^2") do
        f(x) = x^2
        x, ef, fx, fdx, iter, el_time = newton(f, 1.0)
        @fact x --> roughly(0.0, 1e-3)
        @fact ef --> 0
        @fact fx --> roughly(0.0, 1e-6)
        @fact fdx --> roughly(0.0, 2e-3)
        @fact iter --> less_than(1000)
        @fact el_time --> less_than(60)
    end
end

context("Não quebre") do
    facts("f'(x) = 0") do
        f(x) = x^2 - 1
        x0 = 0.0
        x, ef, fx, fdx, iter, el_time = newton(f, x0)
        @fact ef --> -1 # -1 -> derivada zero
    end
    facts("Escala") do
        for p = [1e8; 1e-8]
            f(x) = p * (x^2 - 4)
            x, ef, fx, fdx, iter, el_time = newton(f, 1)
            @fact x --> roughly(2.0, 1e-3)
            @fact fx --> roughly(0.0, 1e-6)
            @fact ef --> 0
        end
    end
    facts("Longe da solução") do
        f(x) = x^2/(1+x^2)
        x0 = 2.0
        x, ef, fx, fdx, iter, el_time = newton(f, x0)
        @fact abs(x) --> greater_than(100)
        @fact ef --> not(0)
    end
end

context("Sem loop infinito") do
    f(x) = x^4
    x0 = 1.0
    facts("Iterações") do
        x, ef, fx, fdx, iter, el_time = newton(f, x0, maxiter=1)
        @fact ef --> not(0)
        @fact iter --> 1
    end
    
    facts("Tempo") do
        x, ef, fx, fdx, iter, el_time = newton(f, x0, maxtime=0.0)
        @fact ef --> not(0)
        @fact el_time --> greater_than(0.0)
    end
end
# Out:
#   > Exemplos básicos
# f(x) = x^2 - 1
# 5 facts verified.
# f(x) = x^2
# 6 facts verified.
#   > Não quebre
# f'(x) = 0
# 1 fact verified.
# Escala
# 6 facts verified.
# Longe da solução
# 2 facts verified.
#   > Sem loop infinito
# Iterações
# 2 facts verified.
# Tempo
# 2 facts verified.
# delayed_handler (generic function with 4 methods)

# %%
function secante(f, x; tol_f = 1e-6, tol_x = 1e-3,
        maxiter = 1000, maxtime = 60)
    d = 1
    iter = 0
    ef = 0
    start_time = time()
    el_time = 0.0
    while abs(f(x)) > tol_f || abs(d) > tol_x
        x1 = x + d
        m = (f(x1) - f(x))/(x1 - x)
        d = -f(x1)/m
        x = x1
        iter += 1
        el_time = time() - start_time
        if iter >= maxiter
            ef = 1
            break
        end
        if el_time >= maxtime
            ef = 2
            break
        end
    end
    return x, ef, f(x), iter, el_time
end
# Out:
# secante (generic function with 1 method)

# %%
x, ef, fx, iter, el_time = secante(x->x^2 - 2, 1)
# Out:
# (1.4142135620573204,0,-8.931455575122982e-10,6,0.002933979034423828)

# %%
context("Exemplos básicos") do
    facts("f(x) = x^2 - 1") do
        f(x) = x^2-1
        x, ef, fx, iter, el_time = secante(f, 1.0)
        @fact x --> roughly(1.0, 1e-6)
        @fact ef --> 0
        @fact fx --> roughly(0.0, 1e-6)
        @fact iter --> less_than(1000)
        @fact el_time --> less_than(60)
    end
    
    facts("f(x) = x^2") do
        f(x) = x^2
        x, ef, fx, iter, el_time = secante(f, 1.0)
        @fact x --> roughly(0.0, 1e-3)
        @fact ef --> 0
        @fact fx --> roughly(0.0, 1e-6)
        @fact iter --> less_than(1000)
        @fact el_time --> less_than(60)
    end
end

context("Não quebre") do
    facts("f'(x) = 0") do
        f(x) = x^2 - 1
        x0 = 0.0
        x, ef, fx, iter, el_time = secante(f, x0)
        @fact x --> roughly(1.0, 1e-6)
        @fact ef --> 0
        @fact fx --> roughly(0.0, 1e-6)
        @fact iter --> less_than(1000)
        @fact el_time --> less_than(60)    end
    facts("Escala") do
        for p = [1e8; 1e-8]
            f(x) = p * (x^2 - 4)
            x, ef, fx, iter, el_time = secante(f, 1)
            @fact x --> roughly(2.0, 1e-3)
            @fact fx --> roughly(0.0, 1e-6)
            @fact ef --> 0
        end
    end
end

context("Sem loop infinito") do
    f(x) = x^4
    x0 = 1.0
    facts("Iterações") do
        x, ef, fx, iter, el_time = secante(f, x0, maxiter=1)
        @fact ef --> not(0)
        @fact iter --> 1
    end
    
    facts("Tempo") do
        x, ef, fx, iter, el_time = secante(f, x0, maxtime=0.0)
        @fact ef --> not(0)
        @fact el_time --> greater_than(0.0)
    end
end
# Out:
#   > Exemplos básicos
# f(x) = x^2 - 1
# 5 facts verified.
# f(x) = x^2
# 5 facts verified.
#   > Não quebre
# f'(x) = 0
# 5 facts verified.
# Escala
# 6 facts verified.
#   > Sem loop infinito
# Iterações
# 2 facts verified.
# Tempo
# 2 facts verified.
# delayed_handler (generic function with 4 methods)

# %%
gr()
m = 2
b, a = -5m+10, 8m-17
f(x) = x < 2 ? x^2-1 : 3 + 4*(x-2) + a*(x-2)^2 + b*(x-2)^3
g(x) = ForwardDiff.derivative(f, x)
plot(f, -0.2, 3.5, leg=false)
plot!(x->f(3) + g(3)*(x-3), -0.2, 3.5)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="561" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.7374,371.481 65.7374,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   217.259,371.481 217.259,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   368.781,371.481 368.781,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   520.302,371.481 520.302,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,330.442 587.654,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,213.833 587.654,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,97.2242 587.654,97.2242
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 596.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 596.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.7374,377.078 65.7374,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.7374,3.93701 65.7374,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   217.259,377.078 217.259,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   217.259,3.93701 217.259,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   368.781,377.078 368.781,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   368.781,3.93701 368.781,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   520.302,377.078 520.302,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   520.302,3.93701 520.302,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,377.078 596.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,330.442 43.8425,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,330.442 587.654,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,213.833 43.8425,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,213.833 587.654,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,97.2242 43.8425,97.2242
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,97.2242 587.654,97.2242
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 65.7374, 393.878)" x="65.7374" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 217.259, 393.878)" x="217.259" y="393.878">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 368.781, 393.878)" x="368.781" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.302, 393.878)" x="520.302" y="393.878">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 334.942)" x="29.4331" y="334.942">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 218.333)" x="29.4331" y="218.333">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 101.724)" x="29.4331" y="101.724">5.0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,375.22 41.096,375.852 46.7589,376.354 52.4219,376.726 58.0848,376.967 63.7477,377.078 69.4106,377.058 75.0736,376.909 80.7365,376.629 86.3994,376.219
#   92.0624,375.678 97.7253,375.007 103.388,374.206 109.051,373.274 114.714,372.213 120.377,371.021 126.04,369.698 131.703,368.245 137.366,366.662 143.029,364.949
#   148.692,363.105 154.355,361.132 160.017,359.027 165.68,356.793 171.343,354.428 177.006,351.933 182.669,349.307 188.332,346.552 193.995,343.666 199.658,340.649
#   205.321,337.503 210.984,334.226 216.647,330.818 222.31,327.281 227.973,323.613 233.636,319.815 239.298,315.886 244.961,311.828 250.624,307.639 256.287,303.319
#   261.95,298.87 267.613,294.29 273.276,289.579 278.939,284.739 284.602,279.768 290.265,274.667 295.928,269.435 301.591,264.073 307.254,258.581 312.917,252.959
#   318.579,247.206 324.242,241.323 329.905,235.31 335.568,229.166 341.231,222.892 346.894,216.488 352.557,209.953 358.22,203.289 363.883,196.493 369.546,189.57
#   375.209,182.68 380.872,175.92 386.535,169.291 392.198,162.791 397.86,156.422 403.523,150.184 409.186,144.075 414.849,138.097 420.512,132.249 426.175,126.532
#   431.838,120.945 437.501,115.488 443.164,110.161 448.827,104.965 454.49,99.8988 460.153,94.9632 465.816,90.1578 471.479,85.4827 477.141,80.9379 482.804,76.5235
#   488.467,72.2393 494.13,68.0855 499.793,64.0619 505.456,60.1687 511.119,56.4057 516.782,52.7731 522.445,49.2707 528.108,45.8987

# %%
gr()
#f(x) = x < 2 ? x^2-1 : 3 + 4*(x-2) - (x-2)^3
function f(x)
    if x < 2
        return x^2 - 1
    else
        return 3 + 4*(x-2) - (x-2)^2
    end
end
g(x) = ForwardDiff.derivative(f, x)
plot(f, -0.2, 3.5, leg=false)
plot!(x->f(3) + g(3)*(x-3), -0.2, 3.5)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.4331,377.078 596.063,377.078 596.063,3.93701 35.4331,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="3" width="561" height="374"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   65.7374,371.481 65.7374,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   217.259,371.481 217.259,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   368.781,371.481 368.781,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   520.302,371.481 520.302,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,330.442 587.654,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,213.833 587.654,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.8425,97.2242 587.654,97.2242
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 596.063,377.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,3.93701 596.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.7374,377.078 65.7374,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   65.7374,3.93701 65.7374,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   217.259,377.078 217.259,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   217.259,3.93701 217.259,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   368.781,377.078 368.781,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   368.781,3.93701 368.781,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   520.302,377.078 520.302,371.481
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   520.302,3.93701 520.302,9.53412
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,377.078 35.4331,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,377.078 596.063,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,330.442 43.8425,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,330.442 587.654,330.442
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,213.833 43.8425,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,213.833 587.654,213.833
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,97.2242 43.8425,97.2242
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,97.2242 587.654,97.2242
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 65.7374, 393.878)" x="65.7374" y="393.878">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 217.259, 393.878)" x="217.259" y="393.878">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 368.781, 393.878)" x="368.781" y="393.878">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.302, 393.878)" x="520.302" y="393.878">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 334.942)" x="29.4331" y="334.942">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 218.333)" x="29.4331" y="218.333">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.4331, 101.724)" x="29.4331" y="101.724">5.0</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   35.4331,375.22 41.096,375.852 46.7589,376.354 52.4219,376.726 58.0848,376.967 63.7477,377.078 69.4106,377.058 75.0736,376.909 80.7365,376.629 86.3994,376.219
#   92.0624,375.678 97.7253,375.007 103.388,374.206 109.051,373.274 114.714,372.213 120.377,371.021 126.04,369.698 131.703,368.245 137.366,366.662 143.029,364.949
#   148.692,363.105 154.355,361.132 160.017,359.027 165.68,356.793 171.343,354.428 177.006,351.933 182.669,349.307 188.332,346.552 193.995,343.666 199.658,340.649
#   205.321,337.503 210.984,334.226 216.647,330.818 222.31,327.281 227.973,323.613 233.636,319.815 239.298,315.886 244.961,311.828 250.624,307.639 256.287,303.319
#   261.95,298.87 267.613,294.29 273.276,289.579 278.939,284.739 284.602,279.768 290.265,274.667 295.928,269.435 301.591,264.073 307.254,258.581 312.917,252.959
#   318.579,247.206 324.242,241.323 329.905,235.31 335.568,229.166 341.231,222.892 346.894,216.488 352.557,209.953 358.22,203.289 363.883,196.493 369.546,189.57
#   375.209,182.68 380.872,175.92 386.535,169.291 392.198,162.791 397.86,156.422 403.523,150.184 409.186,144.075 414.849,138.097 420.512,132.249 426.175,126.532
#   431.838,120.945 437.501,115.488 443.164,110.161 448.827,104.965 454.49,99.8988 460.153,94.9632 465.816,90.1578 471.479,85.4827 477.141,80.9379 482.804,76.5235
#   488.467,72.2393 494.13,68.0855 499.793,64.0619 505.456,60.1687 511.119,56.4057 516.782,52.7731 522.445,49.2707 528.108,45.8987
