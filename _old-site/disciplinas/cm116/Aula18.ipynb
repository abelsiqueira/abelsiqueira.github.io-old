# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
function espectral_forward(κ)
    N = 100
    e = ones(N)
    A = spdiagm((κ*e[1:N-1], (1-2κ)*e, κ*e[1:N-1]), (-1,0,1), N, N)
    ρ = maximum(map(abs, eigs(A, which=:BE, nev=2)[1]))
    return ρ
end
# Out:
# espectral_forward (generic function with 1 method)

# %%
plot(espectral_forward, 0.4, 0.51)
# Out:
# [Plots.jl] Initializing backend: gr
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <polygon clip-path="url(#clip00)" points="
# 75,350 570,350 570,20 75,20
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,336.8 570,336.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,310.4 570,310.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,284 570,284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,257.6 570,257.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,231.2 570,231.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,204.8 570,204.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,178.4 570,178.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,152 570,152
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,125.6 570,125.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,99.2 570,99.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,72.8 570,72.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,46.4 570,46.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   120,350 120,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   165,350 165,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   210,350 210,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255,350 255,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   300,350 300,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   345,350 345,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   390,350 390,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435,350 435,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   480,350 480,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   525,350 525,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 288.23)" x="41.9528" y="288.23">1.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 156.23)" x="41.9528" y="156.23">1.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 24.2299)" x="41.9528" y="24.2299">1.04</text>
# </g>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 75,336.8 79.4619,336.8 75,336.8 75,310.4 79.4619,310.4 75,310.4 75,284 83.9237,284 75,284
#   75,257.6 79.4619,257.6 75,257.6 75,231.2 79.4619,231.2 75,231.2 75,204.8 79.4619,204.8 75,204.8 75,178.4
#   79.4619,178.4 75,178.4 75,152 83.9237,152 75,152 75,125.6 79.4619,125.6 75,125.6 75,99.2 79.4619,99.2
#   75,99.2 75,72.8 79.4619,72.8 75,72.8 75,46.4 79.4619,46.4 75,46.4 75,20 83.9237,20 75,20
#   75,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 60.7073, 367.74)" x="60.7073" y="367.74">0.40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 285.707, 367.74)" x="285.707" y="367.74">0.45</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 510.707, 367.74)" x="510.707" y="367.74">0.50</text>
# </g>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 75,350 75,341.076 75,350 120,350 120,345.538 120,350 165,350 165,345.538 165,350
#   210,350 210,345.538 210,350 255,350 255,345.538 255,350 300,350 300,341.076 300,350 345,350
#   345,345.538 345,350 390,350 390,345.538 390,350 435,350 435,345.538 435,350 480,350 480,345.538
#   480,350 525,350 525,341.076 525,350 570,350 570,345.538 570,350
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,336.8 565.538,336.8 570,336.8 570,310.4 565.538,310.4 570,310.4 570,284 561.076,284 570,284
#   570,257.6 565.538,257.6 570,257.6 570,231.2 565.538,231.2 570,231.2 570,204.8 565.538,204.8 570,204.8 570,178.4
#   565.538,178.4 570,178.4 570,152 561.076,152 570,152 570,125.6 565.538,125.6 570,125.6 570,99.2 565.538,99.2
#   570,99.2 570,72.8 565.538,72.8 570,72.8 570,46.4 565.538,46.4 570,46.4 570,20 561.076,20 570,20
#   570,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,20 75,20 75,28.9237 75,20 120,20 120,24.4619 120,20 165,20 165,24.4619 165,20
#   210,20 210,24.4619 210,20 255,20 255,24.4619 255,20 300,20 300,28.9237 300,20 345,20
#   345,24.4619 345,20 390,20 390,24.4619 390,20 435,20 435,24.4619 435,20 480,20 480,24.4619
#   480,20 525,20 525,28.9237 525,20 570,20 570,24.4619 570,20
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,286.554 75.8264,286.555 76.6528,286.556 77.4791,286.558 78.3055,286.559 79.1319,286.56 79.9583,286.561 80.7846,286.562 81.611,286.563 82.4374,286.565
#   83.2638,286.566 84.0902,286.567 84.9165,286.568 85.7429,286.569 86.5693,286.57 87.3957,286.572 88.222,286.573 89.0484,286.574 89.8748,286.575 90.7012,286.576
#   91.5275,286.577 92.3539,286.579 93.1803,286.58 94.0067,286.581 94.8331,286.582 95.6594,286.583 96.4858,286.585 97.3122,286.586 98.1386,286.587 98.9649,286.588
#   99.7913,286.589 100.618,286.59 101.444,286.592 102.27,286.593 103.097,286.594 103.923,286.595 104.75,286.596 105.576,286.597 106.402,286.599 107.229,286.6
#   108.055,286.601 108.881,286.602 109.708,286.603 110.534,286.604 111.361,286.606 112.187,286.607 113

# %%
function calor_forward(u0, T0, c, L, tf; N = 10, minM = 1)
    h = L/(N-1)
    x = linspace(0, L, N)
    M = max( ceil(Int, 2tf*c/(h^2)), minM)
    t = linspace(0, tf, M+1)
    δ = tf/M
    
    # Cada coluna de V é Vⁿ, isto é vᵢⁿ = V[i,n]
    V = zeros(N, M+1) # Não esquecer do n = 0
    V[1,1] = T0
    for i = 2:N-1
        V[i,1] = u0(x[i])
    end
    V[N,1] = T0
    κ = c*δ/h^2
    for n = 1:M
        V[1,n+1] = T0
        for i = 2:N-1
            V[i,n+1] = κ*V[i+1,n] + (1-2κ)*V[i,n] + κ*V[i-1,n]
        end
        V[N,n+1] = T0
    end
    return t, x, V
end
# Out:
# calor_forward (generic function with 1 method)

# %%
u0(x) = exp(-(x-0.5)^2*50)*100 + 10
T0 = 10.0
c = 0.25
L = 10.0
tf = 15.0
N = 100

fps = 15
minM = ceil(Int, fps*tf)

t, x, V = calor_forward(u0, T0, c, L, tf; N = N, minM=minM);

M = length(t)
step = ceil(Int, M/(tf*fps))

anim = Animation()
umax = maximum(V)

for k = 1:step:M
    plot(x, V[:,k], c=:red)
    title!("$(round(t[k],2)) s")
    ylims!(-0.1, umax)
    frame(anim)
end
gif(anim, "tmp.gif", fps=fps)
# Out:
# INFO: Saved animation to /home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif
# Plots.AnimatedGif("/home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif")

# %%
function espectral_backward(κ)
    N = 100
    e = ones(N)
    A = spdiagm((-κ*e[1:N-1], (1+2κ)*e, -κ*e[1:N-1]), (-1,0,1), N, N)
    ρ = 1/abs(eigs(A, which=:SM, nev=1)[1][1])
    return ρ
end
# Out:
# espectral_backward (generic function with 1 method)

# %%
plot(espectral_backward, 0.0, 100.0)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <polygon clip-path="url(#clip00)" points="
# 75,350 570,350 570,20 75,20
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,342.667 570,342.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,328 570,328
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,313.333 570,313.333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,298.667 570,298.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,284 570,284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,269.333 570,269.333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,254.667 570,254.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,240 570,240
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,225.333 570,225.333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,210.667 570,210.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,196 570,196
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,181.333 570,181.333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,166.667 570,166.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,152 570,152
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,137.333 570,137.333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,122.667 570,122.667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,108 570,108
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,93.3333 570,93.3333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,78.6667 570,78.6667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,64 570,64
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,49.3333 570,49.3333
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,34.6667 570,34.6667
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   94.8,350 94.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   114.6,350 114.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   134.4,350 134.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   154.2,350 154.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   174,350 174,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   193.8,350 193.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   213.6,350 213.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   233.4,350 233.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   253.2,350 253.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   273,350 273,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   292.8,350 292.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   312.6,350 312.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   332.4,350 332.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   352.2,350 352.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   372,350 372,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   391.8,350 391.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   411.6,350 411.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   431.4,350 431.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   451.2,350 451.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471,350 471,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   490.8,350 490.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   510.6,350 510.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   530.4,350 530.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   550.2,350 550.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 317.563)" x="41.9528" y="317.563">0.92</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 244.23)" x="41.9528" y="244.23">0.94</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 170.897)" x="41.9528" y="170.897">0.96</text>
# </g>
# <g

# %%
function calor_backward(u0, T0, c, L, tf; N = 10, minM = 1)
    h = L/(N-1)
    x = linspace(0, L, N)
    M = max( ceil(Int, 2tf*c/(h^2)), minM)
    t = linspace(0, tf, M+1)
    δ = tf/M
    
    # Cada coluna de V é Vⁿ, isto é vᵢⁿ = V[i,n]
    V = zeros(N, M+1) # Não esquecer do n = 0
    V[1,1] = T0
    for i = 2:N-1
        V[i,1] = u0(x[i])
    end
    V[N,1] = T0
    κ = c*δ/h^2
    e = ones(N-2)
    A = spdiagm((-κ*e[1:N-3], (1+2κ)*e, -κ*e[1:N-3]), (-1,0,1), N-2, N-2)
    for n = 1:M
        V[1,n+1] = T0
        w = V[2:N-1,n]
        w[1] += κ*T0
        w[end] += κ*T0
        V[2:N-1,n+1] = A\w
        V[N,n+1] = T0
    end
    return t, x, V
end
# Out:
# calor_backward (generic function with 1 method)

# %%
u0(x) = exp(-(x-0.5)^2*50)*100 + 10
T0 = 10.0
c = 0.25
L = 10.0
tf = 15.0
N = 100

fps = 15
minM = ceil(Int, fps*tf)

t, x, V = calor_backward(u0, T0, c, L, tf; N = N, minM=minM);

M = length(t)
step = ceil(Int, M/(tf*fps))

anim = Animation()
umax = maximum(V)

for k = 1:step:M
    plot(x, V[:,k], c=:red)
    title!("$(round(t[k],2)) s")
    ylims!(-0.1, umax)
    frame(anim)
end
gif(anim, "tmp.gif", fps=fps)
# Out:
# INFO: Saved animation to /home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif
# Plots.AnimatedGif("/home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif")

# %%
u0(x) = exp(-(x-0.5)^2*50)*10 + 10
T0 = 10.0
c = 0.01
L = 2.0
tf = 15.0
N = 100

fps = 15
minM = ceil(Int, fps*tf)

t, x, VF = calor_forward(u0, T0, c, L, tf; N = N, minM=minM);
t, x, VB = calor_backward(u0, T0, c, L, tf; N = N, minM=minM);

M = length(t)
step = ceil(Int, M/(tf*fps))

anim = Animation()
umin, umax = extrema(VF-VB)

for k = 1:step:M
    plot(x, VF[:,k]-VB[:,k], c=:red)
    #plot(x, VB[:,k], c=:blue)
    title!("$(round(t[k],2)) s")
    ylims!(umin, umax)
    frame(anim)
end
gif(anim, "tmp.gif", fps=fps)
# Out:
# INFO: Saved animation to /home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif
# Plots.AnimatedGif("/home/abel/projetos/abelsiqueira.github.io/disciplinas/cm116/tmp.gif")

# %%
function espectral_crank(κ)
    N = 100
    e = ones(N)
    A = spdiagm((-κ*e[1:N-1], (1+2κ)*e, -κ*e[1:N-1]), (-1,0,1), N, N)
    B = spdiagm((κ*e[1:N-1], (1-2κ)*e, κ*e[1:N-1]), (-1,0,1), N, N)
    C = inv(full(A))*B
    ρ = maximum(map(abs, eig(C)[1]))
    return ρ
end
# Out:
# espectral_crank (generic function with 1 method)

# %%
plot(espectral_crank, 0.0, 100.0)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <polygon clip-path="url(#clip00)" points="
# 75,350 570,350 570,20 75,20
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,339.355 570,339.355
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,318.065 570,318.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,296.774 570,296.774
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,275.484 570,275.484
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,254.194 570,254.194
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,232.903 570,232.903
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,211.613 570,211.613
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,190.323 570,190.323
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,169.032 570,169.032
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,147.742 570,147.742
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,126.452 570,126.452
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,105.161 570,105.161
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,83.871 570,83.871
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,62.5806 570,62.5806
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,41.2903 570,41.2903
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   94.8,350 94.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   114.6,350 114.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   134.4,350 134.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   154.2,350 154.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   174,350 174,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   193.8,350 193.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   213.6,350 213.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   233.4,350 233.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   253.2,350 253.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   273,350 273,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   292.8,350 292.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   312.6,350 312.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   332.4,350 332.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   352.2,350 352.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   372,350 372,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   391.8,350 391.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   411.6,350 411.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   431.4,350 431.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   451.2,350 451.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471,350 471,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   490.8,350 490.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   510.6,350 510.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   530.4,350 530.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   550.2,350 550.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 343.585)" x="41.9528" y="343.585">0.97</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 237.133)" x="41.9528" y="237.133">0.98</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 130.681)" x="41.9528" y="130.681">0.99</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 41.9528, 24.2299)" x="41.9528" y="24.2299">1.00</text>
# </g>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 75,339.355 83.9237,339.355 75,339.355 75,318.065 79.4619,318.065 75,318.065 75,296.774 79.4619,296.774 75,296.774
#   75,275.484 79.4619,275.484 75,275.484 75,254.194 79.4619,254.194 75,254.194 75,232.903 83.9237,232.903 75,232.903 75,211.613
#   79.4619,211.613 75,211.613 75,190.323 79.4619,190.323 75,190.323 75,169.032 79.4619,169.032 75,169.032 75,147.742 79.4619,147.742
#   75,147.742 75,126.452 83.9237,126.452 75,126.452 75,105.161 79.4619,105.161 75,105.161 75,83.871 79.4619,83.871 75,83.871
#   75,62.5806 79.4619,62.5806 75,62.5806 75,41.2903 79.4619,41.2903 75,41.2903 75,20 83.9237,20 75,20 75,20
#
#   "/>
# <g clip-path="url(#c

# %%
function calor_crank(u0, T0, c, L, tf; N = 10, minM = 1)
    h = L/(N-1)
    x = linspace(0, L, N)
    M = max( ceil(Int, 2tf*c/(h^2)), minM)
    t = linspace(0, tf, M+1)
    δ = tf/M
    
    # Cada coluna de V é Vⁿ, isto é vᵢⁿ = V[i,n]
    V = zeros(N, M+1) # Não esquecer do n = 0
    V[1,1] = T0
    for i = 2:N-1
        V[i,1] = u0(x[i])
    end
    V[N,1] = T0
    κ = c*δ/(2h^2)
    e = ones(N-2)
    A = spdiagm((-κ*e[1:N-3], (1+2κ)*e, -κ*e[1:N-3]), (-1,0,1), N-2, N-2)
    B = spdiagm((κ*e[1:N-3], (1-2κ)*e, κ*e[1:N-3]), (-1,0,1), N-2, N-2)
    for n = 1:M
        V[1,n+1] = T0
        w = V[2:N-1,n]
        w[1] += κ*T0
        w[end] += κ*T0
        V[2:N-1,n+1] = A\(B*w)
        V[N,n+1] = T0
    end
    return t, x, V
end
# Out:
# calor_crank (generic function with 1 method)

# %%
L = 1.0
u0(x) = sin(π*x)
T0 = 0.0
c = 0.01
tf = 6.0
N = 200

minM = 1

t, x, VF = calor_forward(u0, T0, c, L, tf; N = N, minM=minM);
t, x, VB = calor_backward(u0, T0, c, L, tf; N = N, minM=minM);
t, x, VC = calor_crank(u0, T0, c, L, tf; N = N, minM=minM);

u(t,x) = exp(-t*c*π^2)*sin(π*x)

M = length(t)
U = zeros(N, M)
for n = 1:M
    for i = 1:N
        U[i,n] = u(t[n],x[i])
    end
end

println("Erro Forward:  ", vecnorm(VF-U))
println("Erro Backward: ", vecnorm(VB-U))
println("Erro Crank:    ", vecnorm(VC-U))

plot(x->u(t[end],x), 0, L)
plot!(x, VF[:,end], c=:red)
plot!(x, VB[:,end], c=:green)
plot!(x, VC[:,end], c=:magenta)
# Out:
# Erro Forward:  0.006351615005339686
# Erro Backward: 0.012703265257978217
# Erro Crank:    0.0031762957364932444
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <polygon clip-path="url(#clip00)" points="
# 75,350 570,350 570,20 75,20
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,328 570,328
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,306 570,306
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,284 570,284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,262 570,262
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,240 570,240
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,218 570,218
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,196 570,196
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,174 570,174
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,152 570,152
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,130 570,130
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,108 570,108
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,86 570,86
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,64 570,64
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,42 570,42
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,20 570,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   94.8,350 94.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   114.6,350 114.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   134.4,350 134.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   154.2,350 154.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   174,350 174,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   193.8,350 193.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   213.6,350 213.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   233.4,350 233.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   253.2,350 253.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   273,350 273,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   292.8,350 292.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   312.6,350 312.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   332.4,350 332.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   352.2,350 352.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   372,350 372,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   391.8,350 391.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   411.6,350 411.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   431.4,350 431.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   451.2,350 451.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471,350 471,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   490.8,350 490.8,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   510.6,350 510.6,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   530.4,350 530.4,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   550.2,350 550.2,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 62.3709, 354.23)" x="62.3709" y="354.23">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 244.23)" x="50.12" y="244.23">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 134.23)" x="50.12" y="134.23">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 24.2299)" x="50.12" y="24.2299">0.6</text>
# </g>
# <polyline clip-path="url(#clip00)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 75,350 83.9237,350 75,350 75,328 79.4619,328 75,328 75,306 79.4619,306 75,306
#   75,284 79.4619,284 75,284 75,262 79.4619,262 75,262 75,240 83.9237,240 75,240 75,218
#   79.4619,218 75,218 75,196 79.4619,196 75,196 75,174 79.4619,174 75,174 75,152 79.4619,152
#   75,152 75,130 83.9237,130 75,130 75,108 79.4619,108 75,108 75,86 79.4619,86 75,86
#   75,64 79.4619,64 75,64 75,42 79.4619,42 75,42 75,20 83.9237,20 75,20
#
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 70.9164, 367.74)" x="70.9164" y="367.74">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 163.791, 367.74
