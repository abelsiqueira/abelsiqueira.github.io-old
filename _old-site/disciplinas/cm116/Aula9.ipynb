# %% [markdown]
# # Plots.jl + GR ou PyPlot

# %%
# Instala o Plots, o GR e o PyPlot
#Pkg.add("Plots")
#Pkg.add("GR")
Pkg.add("PyPlot")

# %%
# Usa o Plots na versao de desenvolvimento
Pkg.checkout("Plots", "dev")

# %%
using Plots

# %%
#pyplot()
x = linspace(0, 1, 10)
y = x.^2
t, y = euler(coisos)
# y provavelmente eh um vetor
plot!(x,1-y)
# Out:
# LoadError: UndefVarError: euler not defined
# while loading In[2], in expression starting on line 4

# %%
# Retornando t e w para plotar
function euler_explicito(f, t0, y0, tf; n = 10)
    t = linspace(t0, tf, n+1) # ou t = 0.0:h:1.0
    if length(y0) == 1
        w = zeros(n+1) # Vetor
    else
        w = zeros(n+1,length(y0))
    end
    w[1,:] = y0
    h = (tf-t0)/n

    for i = 1:n
        w[i+1,:] = w[i,:][:] + h*f(t[i],w[i,:])
    end

    return t, w
end
# Out:
# euler_explicito (generic function with 1 method)

# %%
# Sistema dinamico
# x' = -y
# y' = x
f(t,Y) =[-Y[2]; Y[1]]
Y0 = [1.0; 1.0]
t0 = 0
tf = 1
N = 100
t, W = euler_explicito(f, t0, Y0, tf; n = N);
plot(W[:,1], W[:,2], leg=false) #leg=false remove legenda
# Out:
# [Plots.jl] Initializing backend: pyplot
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 34.7725 263.2975
# L 412.67875 263.2975
# L 412.67875 16.83125
# L 34.7725 16.83125
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
# ...

# %%
surface(x, x, x.^2 .+ x'.^2)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;stroke-miterlimit:100000;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 432 288
# L 432 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="patch_2">
#    <path d="M 12.96 275.04
# L 337.824 275.04
# L 337.824 12.96
# L 12.96 12.96
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="pane3d_1">
#    <g id="patch_3">
#     <path d="M 56.025743 217.129556
# L 149.00352 152.873479
# L 147.455538 30.09066
# L 49.293642 87.823425
# ...

# %%
anim = Animation()
for j = 1:10:N
    plot(W[1:j,1], W[1:j,2])
    frame(anim)
end
gif(anim, "tmp.gif")
